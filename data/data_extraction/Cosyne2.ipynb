# %%
# making authors list
def make_authors_list_from_csv(filename):
    authors_list = []
    with open(filename+'.csv') as f:
        next(f)
        for line in f:
            split = line.split('|')
            authors = split[2].split(',')            
            authors_clean = []
            for author in authors:
                authors_clean.append(author.lstrip())
            # authors list
            for author in authors_clean:
                author= author.lstrip()
                if not(author in authors_list):
                    authors_list.append(author.lstrip())        
    authors_list = sorted(authors_list)
    authors_dict = {}
    i = 0
    for author in authors_list:
        authors_dict[author] = i
        i+=1
    return authors_list,authors_dict



# making dictionnary for indexing author   
# construction poster dictionary  
# for each poster: the list of collaborators
def make_poster_dict_from_csv(filename):
    poster_count = {}
    poster_dict = {}
    with open(filename+'.csv') as f:
        next(f)
        for line in f:
            split = line.split('|')
            posterid = int(split[0])
            authors = split[2].split(',')            
            authors_id = []
            for author in authors:
                author = author.lstrip()
                authors_id.append(authors_dict[author.lstrip()])
                if author in poster_count:
                    poster_count[author]+=1
                else:
                    poster_count[author]=1
            poster_dict[posterid] = authors_id
    return poster_dict,poster_count  


def make_pairs(l1,l2):
    if len(l1)>0:
        #print [l1,l2]
        for i in range(len(l1)):
            l2.append([l1[0],l1[i]])
        make_pairs(l1[1:],l2)
    else:
        return l2
    return l2
        

# Listing of pairwise collaboration
def make_pairwise_dictionary(poster_dict):
    pair_dict = {}
    for p in poster_dict:
        a = poster_dict[p]
        pairs = make_pairs(a,[])
        #print a, pairs
        for pair in pairs:
            pair = tuple(pair)
            if pair in pair_dict:
                pair_dict[pair]+=1
            else:
                pair_dict[pair]=1
    return pair_dict


# Connex

def make_connected_components(pair_dict):
    import networkx as nx
    G=nx.Graph()
    G.add_nodes_from(range(len(pair_dict)))
    G.add_edges_from(pair_dict.keys())
    return  nx.connected_components(G)



# crop small clusters
def crop_graph(graph,Nmin):
    croped_graph = [];
    for group in graph:
        if len(group)>Nmin:
            croped_graph.append(group)
    return croped_graph

# %%
filename = 'AbstractsCosyne2012'
authors_list,authors_dict = make_authors_list_from_csv(filename)
poster_dict,poster_count = make_poster_dict_from_csv(filename)
pair_dict = make_pairwise_dictionary(poster_dict)
cc = make_connected_components(pair_dict)
cc_crop = crop_graph(cc,20)

# %%
# generating json file
import os
def makejson(cc,authors_list,pair_dict, filename):
    
    authorsids = [item for sublist in cc for item in sublist]
    newids = range(len(authorsids))
    old_to_new = {}
    for new in newids:
        old_to_new[authorsids[new]] = new
        
    with open(filename+".json", "w") as outfile:
        #nodes
        outfile.write("{\n\"nodes\":[\n")
        for newid in newids:
            oldid = authorsids[newid]
            for i_group in range(len(cc)):
                for author_in_group in cc[i_group]:
                    if (oldid == author_in_group):
                        value = i_group
                        outfile.write("{\"name\":\"" + authors_list[oldid] +"\",\"group\":"+str(value+1)+"},\n" )
        outfile.seek(-2, os.SEEK_END)
        outfile.truncate()
        outfile.write("],\n")
        
        #links
        outfile.write("\"links\":[\n")
        
        keys = pair_dict.keys()
        for i_pair in range(len(keys)):
            pair = keys[i_pair]
            if pair[0] in authorsids and pair[1] in authorsids:
                value = pair_dict[pair]
                outfile.write("{\"source\":" + str(old_to_new[pair[0]]) +",\"target\":"+str(old_to_new[pair[1]])+",\"value\":"+str(value)+"},\n" )    
        outfile.seek(-2, os.SEEK_END)
        outfile.truncate()
        outfile.write("]\n}")

        
        

        
# poster count when multiple poster
def make_json_poster_count(poster_count,filename,number_min=1):
    poster_count_big ={}        
    for poster in poster_count:
        if poster_count[poster]>=number_min:
            poster_count_big[poster]=poster_count[poster]
    print poster_count_big
    with open(filename+".json", "w") as outfile:
        #nodes
        outfile.write("{\n\"names\":[\n")
        outfile.write("{\"name\":\"" + authors_list[oldid] +"\",\"group\":"+str(value+1)+"},\n" )
        outfile.seek(-2, os.SEEK_END)
    
    return poster_count_big    

makejson(cc_crop,authors_list,pair_dict, 'cosyne12_small');
make_json_poster_count(poster_count,'poster_count_big',2);
make_json_poster_count(poster_count,'poster_count');
# Out:
# {'Anthony Zador': 3, "Daniel O'Connor": 2, 'Christian Tetzlaff': 2, 'Byron Yu': 2, 'Mark Churchland': 2, 'Maria Vicente': 2, 'Taro Toyoizumi': 2, 'Mattia Rigotti': 2, 'Krishna Shenoy': 6, 'Alex Kwan': 2, 'Sherika Sylvester': 2, 'Carina Curto': 4, 'Christopher Moore': 2, 'Yushi  Wang': 2, 'Liam Paninski': 4, 'Isaac Carruthers': 2, 'Tyler Lee': 2, 'Ana Raquel Martins': 2, 'Emad Eskandar': 2, 'Greg Horwitz': 2, 'Mark Goldman': 4, 'Daniel Huber': 2, 'Matteo Carandini': 4, 'Zachary Mainen': 4, 'Nikos K. Logothetis': 2, 'DJ Strouse': 2, 'Timothy Gentner': 2, 'Marc Timme': 3, 'Maria Geffen': 2, 'Mikko Juusola': 2, 'Michael DeWeese': 2, 'Tirin Moore': 3, 'Bartlett Mel': 3, 'Karel Svoboda': 2, 'Loren Frank': 2, 'Florentin W\xcb\x86rg\xcb\x86tter': 2, 'Eero Simoncelli': 7, 'Caleb Kemere': 2, 'Tim P. Vogels': 3, 'Brent Doiron': 2, 'Ziv Rotman': 2, 'Chris Rozell': 2, 'Antonello Bonci': 2, 'Aldo Faisal': 4, 'Christoph Kolodziejski': 2, 'Dora Angelaki': 2, 'Rollin Hu': 2, 'Gasper Tkacik': 3, 'Wei Ji Ma': 4, 'David Sussillo': 2, 'Tao Hu': 2, 'Joseph Madsen': 2, 'Nathaniel Daw': 4, 'Maneesh Sahani': 3, 'Eyal Seidemann': 2, 'Matthias Bethge': 2, 'Markus Meister': 2, 'Vitaly Klyachko': 2, 'Alireza Soltani': 2, 'Aaron Suminski': 2, 'Arjun Bharioke': 2, 'Tony Movshon': 4, 'Jianzhong  Jin': 2, 'Robert Rosenbaum': 2, 'Ruben Coen-Cagli': 2, 'Ronald  Van Den Berg': 4, 'Dinu Albeanu': 2, 'Peggy Series': 3, 'Ila Fiete': 5, 'Andrew Fagg': 2, 'Elad Schneidman': 5, 'Alexandre Pouget': 6, 'Julijana Gjorgjieva': 2, 'Michael Buice': 2, 'Joshua Siegle': 2, 'Mate Lengyel': 3, 'A. Moses Lee': 2, 'Stefano Fusi': 2, 'Jakob Macke': 2, "Randall O'Reilly": 2, 'William Newsome': 2, 'Xiao-Jing Wang': 3, 'Odelia Schwartz': 2, 'Baktash Babadi': 2, 'Jose-Manuel Alonso': 2, 'Kayvon Daie': 3, 'Jan Drugowitsch': 2, 'Martin Stemmler': 2, 'James DiCarlo': 2, 'Kresimir Josic': 2, 'Peter Latham': 2, 'Jose Carmena': 2, 'Il Memming Park': 2, 'John Reynolds': 4, 'Raoul-Martin Memmesheimer': 2, 'Daniel Butts': 2, 'Petr Znamenskiy': 2, 'Peter  Dayan': 4, 'Francis Willett': 2, 'Bruno Olshausen': 2, 'Ruben Moreno': 2, 'Alla Karpova': 2, 'Dougal Tervo': 2, 'Misha Tsodyks': 2, 'Paul Schrater': 6, 'Seth Madlon-Kay': 2, 'Andreas V.M. Herz': 3, 'Christoph Kirst': 2, 'Victor  Chan': 2, 'Ziv Williams': 2, 'Eric Shea-Brown': 2, 'Qi Wang': 2, 'Matthew Kaufman': 2, 'Yang Dan': 2, 'Linda Wilbrecht': 2, 'Wulfram Gerstner': 4, 'Jonathan Pillow': 4, 'Melanie Lee': 2, 'Andreas Tolias': 2, 'Vladimir Itskov': 4, 'Fritz Sommer': 3, 'Emre Aksay': 3, 'Christopher Hillar': 2, 'Vivienne Ming': 2, 'Michael Berry': 3, 'Wilson Geisler': 2, 'Anirvan Nandy': 3, 'Nicholas Hatsopoulos': 2, 'Omri Barak': 2, 'Garrett Stanley': 2, 'Paul Nuyujukian': 2, 'Larry Abbott': 5, 'Jeremy Freeman': 2, 'Felix Wichmann': 2, 'Yuzhi Chen': 2, 'Andre Mendonca': 2, 'Robert Froemke': 3, 'Corey Ziemba': 2, 'Henning Sprekeler': 2, 'Paul Bays': 2, 'Ronen Segev': 4, 'Ryan Natan': 2, 'Michael J Frank': 2, 'Emery Brown': 2, 'Stephen Ryu': 5, 'Edward Callaway': 2, 'Jude Mitchell': 3, 'Ran Rubin': 2, 'Adam Kohn': 2, 'Haim Sompolinsky': 6, 'Sydney Cash': 2, 'Michael Platt': 2, 'Kenneth Harris': 2, 'Jeffrey Beck': 4, 'Dmitri Chklovskii': 6, 'Tatyana Sharpee': 5}
# {'Zachary Mayko': 1, 'Gil Costa': 1, 'Laurel Carney': 1, 'Judy Walker': 1, 'Andrew Welchman': 1, 'Garrett Kenyon': 1, 'Melchi Michel': 1, 'Shiming Tang': 1, 'Priyanka Gupta': 1, 'Helen Shen': 1, 'Brian Wandell': 1, 'Sotiris  Masmanidis': 1, 'Thierry Emonet': 1, 'Guillaume Hennequin': 1, 'Hania  Kover': 1, 'Tim Behrens': 1, 'Matthew Koh': 1, 'Ryan Rowekamp': 1, 'Eldon Emberly': 1, 'Jacob Yates': 1, 'Sherika Sylvester': 2, 'Fred Rieke': 1, 'Christopher Moore': 2, 'Jeff Gavornik': 1, 'William Nesse': 1, 'Zachary Lindbloom-Brown': 1, 'Sarah Woolley': 1, 'Lars Buesing': 1, 'Oren Forkosh': 1, 'Eric Chen': 1, 'Mark Goldman': 4, 'Eftychios Pnevmatikakis': 1, 'Alexander Dimitrov': 1, 'Michael Schnabel': 1, 'Kolia Sadeghi': 1, 'Mehrdad Jazayeri': 1, 'DJ Strouse': 2, 'David Morton': 1, 'Chun-Yuan Ting': 1, 'Sean Trettel': 1, 'Friedemann Zenke': 1, 'Tom Daniel': 1, 'Michael Reiser': 1, 'Daniel Wolpert': 1, 'Maria Geffen': 2, 'Xaq Pitkow': 1, 'Cahir O\xc3\xadKane': 1, 'Ralf Haefner': 1, 'Tim P. Vogels': 3, 'Jacqueline Fulvio': 1, 'Bartlett Mel': 3, 'R Channing Moore': 1, 'Geoffrey Goodhill': 1, 'Karel Svoboda': 2, 'Jason Climer': 1, 'Nicholas Price': 1, 'Natalia Shevtsova': 1, 'Mark Frye': 1, 'Gregory W Wornell': 1, 'Mark Zarella': 1, 'Michael  Gedalin': 1, 'John Reppas': 1, 'Grigorios Sotiropoulos': 1, 'Diego Gutnisky': 1, 'KiJung Yoon': 1, 'Yang Yang': 1, 'Brent Doiron': 2, 'Ziv Rotman': 2, 'Dietmar Plenz': 1, 'Chris Rozell': 2, 'Bernardo Sabatini': 1, 'Timothy Buschman': 1, 'Antonio Rangel': 1, 'Matthew Wilson': 1, 'Jeff Pettibone': 1, 'Luke Urban': 1, 'Catherine Dulac': 1, 'Chunyu Duan': 1, 'Mili Milosavljevic': 1, 'Robert Froemke': 3, 'Sven Jahnke': 1, 'Robbe Goris': 1, 'Shantanu Jadhav': 1, 'Joshua Levy': 1, 'Steve  Gotts': 1, 'Bard Ermentrout': 1, 'Gerald Rubin': 1, 'Jaldert Rombouts': 1, 'Kedarnath  Vilankar': 1, 'Alex D. Reyes': 1, 'Joseph Bergan': 1, 'Darin Dougherty': 1, 'Feryal Mehraban Pour Behbahani': 1, 'Alon Rubin': 1, 'Franziska Hellmundt': 1, 'Dirk Walther': 1, 'Stephen Ryu': 5, 'Alon Chen': 1, 'Yarden Cohen': 1, 'Ruben Coen-Cagli': 2, 'Hiroki Asari': 1, 'Christian Leibold': 1, 'Yuwei Cui': 1, 'Julijana Gjorgjieva': 2, 'Manuel Berning': 1, 'A. Moses Lee': 2, 'Lung-Hao Tai': 1, 'Stefano Fusi': 2, 'Stuart Yarrow': 1, 'Pamela  Reinagel': 1, 'Jeffrey Markowitz': 1, 'Gabriel  Kreiman': 1, 'Stefan Everling': 1, 'Kay Thurley': 1, 'Chris Werner': 1, 'Peter Li': 1, 'Garrison Cottrell': 1, 'Jan Drugowitsch': 2, 'Behrad Noudoost': 1, 'Daniel Lee': 1, 'Michael Hasselmo': 1, 'Jeremy K. Seamans': 1, 'Marc Tittgemeyer': 1, 'Ekaterina Vinnik': 1, 'Jeffrey Seely': 1, 'Reza  Lashgari': 1, 'Stephen Williams': 1, 'Benjamin Greenberg': 1, 'Shiv Vitaladevuni': 1, 'Keith Mathieson': 1, 'Chung-Chuan Lo': 1, 'Il Memming Park': 2, 'Christopher Pack': 1, 'Ziqiang Wei': 1, 'Beth Lopour': 1, 'Gordon Logan': 1, 'Daniel Little': 1, 'William Anderson': 1, 'Alain Marchand': 1, 'Itzhak Fried': 1, 'Ruben Moreno': 2, 'Michael T. Lippert': 1, 'Deborah Gunning': 1, 'Gerhard Jocham': 1, 'Anne Collins': 1, 'Danko Nikolic': 1, 'Lorric Ziegler': 1, 'Andreas V.M. Herz': 3, 'Matthew Nassar': 1, 'Terrence Sejnowski': 1, 'Mihaly Kollo': 1, 'Alaina Case': 1, 'Matthew Cook': 1, 'Yoram Ben-Shaul': 1, 'Heesoo  Kim': 1, 'Eric Shea-Brown': 2, 'Dean V. Buonomano': 1, 'Eric Trautman': 1, 'Qi Wang': 2, 'Ha Hong': 1, 'Francoise Dellu-Hagedorn': 1, 'Stan Floresco': 1, 'Jason Fleischer': 1, 'Andreas Tolias': 2, 'Walter Talbott': 1, 'Robert  Desimone': 1, 'Adam Kepecs': 1, 'Fritz Sommer': 3, 'Ahmad Osman': 1, 'Siyu Zhang': 1, 'Shaowen Bao': 1, 'Yu-Chi Huang': 1, 'Eric Reifenstein': 1, 'Michael Berry': 3, 'Fanis Panagiotaropoulos': 1, 'Andrea Barreiro': 1, 'Lou Scheffer': 1, 'James Tee': 1, 'Michoel Snow': 1, 'Xue-Lian Qi': 1, 'Bilal Haider': 1, 'Yaroslav Molkov': 1, 'Alan Litke': 1, 'Jeffrey Smith': 1, 'Larry Abbott': 5, 'Anita Disney': 1, 'Jeremy Freeman': 2, 'Mijung Park': 1, 'Hiroki Terashima': 1, 'Ethan Meyers': 1, 'Christoph Kayser': 1, 'Shaul Druckmann': 1, 'Tatiana Pastern ...

# %%
print """ "a" """
# Out:
#  "a"

# %%
print "a"
# Out:
# a
